# %% [markdown]
# ### FiveThirtyEight Datasets
#
# [favorability_polls()](#favorability_polls(/))
#
# [favorability_averages()](#favorability_averages())
#
# [generic_ballot_polls()](#generic_ballot_polls())
#
# [generic_ballot_polls_historical()](#generic_ballot_polls_historical())
#
# [generic_ballot_averages()](#generic_ballot_averages())
#
# [governor_polls()](#governor_polls())
#
# [governor_polls_historical()](#governor_polls_historical())
#
# [recall_polls()](#recall_polls())
#
# [president_approval_polls()](#president_approval_polls())
#
# [president_approval_polls_historical()](#president_approval_polls_historical())
#
# [vp_approval_polls()](#vp_approval_polls())
#
# [congress_approval()](#congress_approval())
#
# [scotus_approval_polls()](#scotus_approval_polls())
#
# [approval_averages()](#approval_averages())
#
# [president_polls()](#president_polls())
#
# [president_polls_historical()](#president_polls_historical())
#
# [presidential_general_averages()](#presidential_general_averages())
#
# [president_primary_polls()](#president_primary_polls())
#
# [president_primary_polls_historical()](#president_primary_polls_historical())
#
# [presidential_primary_averages()](#presidential_primary_averages())
#
# [house_polls()](#house_polls())
#
# [house_polls_historical()](#house_polls_historical())
#
# [senate_polls()](#senate_polls())
#
# [senate_polls_historical()](#senate_polls_historical())
#
# ___

# %% [markdown]
# Import the fivethirtyeight module

# %%
import ots_backend.fivethirtyeight as fivethirtyeight

# %% [markdown]
# ___
# ### favorability_polls()

# %%
dataset = fivethirtyeight.favorability_polls()
dataset.head()
# Out:
#    poll_id  pollster_id  ... somewhat_unfavorable very_unfavorable
# 0    87162         1302  ...                  8.0             48.0
# 1    87162         1302  ...                 12.0             45.0
# 2    87150          568  ...                  7.0             47.0
# 3    87150          568  ...                  7.0             48.0
# 4    87150          568  ...                 10.0             46.0
#
# [5 rows x 40 columns]

# %% [markdown]
# ___
# ### favorability_averages()

# %%
fa = fivethirtyeight.favorability_averages()
fa.head()
# Out:
#        politician subpopulation       date  ... pct_estimate         lo         hi
# 0  Asa Hutchinson             r 2024-01-09  ...    15.734893  11.494513  19.975273
# 1  Asa Hutchinson             r 2024-01-09  ...    27.367667  20.783565  33.951770
# 2  Asa Hutchinson             r 2024-01-08  ...    15.736815  11.496444  19.977186
# 3  Asa Hutchinson             r 2024-01-08  ...    27.367243  20.783141  33.951345
# 4  Asa Hutchinson             r 2024-01-07  ...    15.737293  11.497384  19.977202
#
# [5 rows x 7 columns]

# %% [markdown]
# ___
# ### generic_ballot_polls()

# %%
gbp = fivethirtyeight.generic_ballot_polls()
gbp.head()
# Out:
#    poll_id  pollster_id          pollster  ...   dem   rep ind
# 0    87162         1302  Echelon Insights  ...  48.0  47.0 NaN
# 1    87150          568            YouGov  ...  44.0  44.0 NaN
# 2    87154          320          Monmouth  ...  45.0  48.0 NaN
# 3    87158         1709       Big Village  ...  39.9  38.1 NaN
# 4    87158         1709       Big Village  ...  43.7  43.0 NaN
#
# [5 rows x 41 columns]

# %% [markdown]
# ___
# ### generic_ballot_polls_historical()

# %%
gpbh = fivethirtyeight.generic_ballot_polls_historical()
gpbh.head()
# Out:
#    poll_id  pollster_id         pollster  ...   dem   rep ind
# 0    81674         1775              GQR  ...  49.0  51.0 NaN
# 1    82892         1365  Change Research  ...  47.0  48.0 NaN
# 2    81616         1528       AtlasIntel  ...  46.6  49.7 NaN
# 3    81616         1528       AtlasIntel  ...  44.1  47.6 NaN
# 4    81621          241            Ipsos  ...  35.0  35.0 NaN
#
# [5 rows x 41 columns]

# %% [markdown]
# ___
# ### generic_ballot_averages()

# %%
gba = fivethirtyeight.generic_ballot_averages()
gba.head()
# Out:
#      candidate  pct_estimate        lo        hi        date   election  cycle
# 0    Democrats      43.94449  39.33347  48.55550  2017-04-15 2018-11-06   2018
# 1  Republicans      39.54969  34.93867  44.16071  2017-04-15 2018-11-06   2018
# 2    Democrats      43.74965  39.14054  48.35876  2017-04-16 2018-11-06   2018
# 3  Republicans      39.59254  34.98343  44.20165  2017-04-16 2018-11-06   2018
# 4    Democrats      43.74553  39.13599  48.35508  2017-04-17 2018-11-06   2018

# %% [markdown]
# ___
# ### governor_polls()

# %%
gp = fivethirtyeight.governor_polls()
gp.head()
# Out:
#    poll_id  pollster_id  ...       candidate_name   pct
# 0    87120         1714  ...       Steve Williams  21.0
# 1    87120         1714  ...     Patrick Morrisey  34.0
# 2    87120         1714  ...     Joe Manchin, III  26.0
# 3    87120         1714  ...  Erika Klie Kolenich   1.0
# 4    87120         1714  ...   Chase Linko-Looper   0.0
#
# [5 rows x 48 columns]

# %% [markdown]
# ___
# ### governor_polls_historical()

# %%
gph = fivethirtyeight.governor_polls_historical()
gph.head()
# Out:
#    poll_id  pollster_id  ... candidate_name   pct
# 0    81623         1677  ...  Charlie Crist  48.0
# 1    81623         1677  ...   Ron DeSantis  52.0
# 2    81629         1250  ...    Katie Hobbs  46.9
# 3    81629         1250  ...      Kari Lake  50.5
# 4    81775         1250  ...  Steve Sisolak  46.1
#
# [5 rows x 48 columns]

# %% [markdown]
# ___
# ### recall_polls()

# %%
rp = fivethirtyeight.recall_polls()
rp.head()
# Out:
#    poll_id  pollster_id  ... Answer 4 Answer 4 pct
# 0    74918         1238  ...      NaN          NaN
# 1    74922          382  ...      NaN          NaN
# 2    74921         1363  ...      NaN          NaN
# 3    74764          460  ...      NaN          NaN
# 4    74920          294  ...      NaN          NaN
#
# [5 rows x 38 columns]

# %% [markdown]
# ___
# ### president_approval_polls()

# %%
pap = fivethirtyeight.president_approval_polls()
pap.head()
# Out:
#    poll_id  pollster_id          pollster  ...   yes    no alternate_answers
# 0    87162         1302  Echelon Insights  ...  41.0  58.0               1.0
# 1    87150          568            YouGov  ...  36.0  59.0               5.0
# 2    87150          568            YouGov  ...  40.0  58.0               2.0
# 3    87161         1447            Civiqs  ...  36.0  57.0               7.0
# 4    87154          320          Monmouth  ...  38.0  58.0               4.0
#
# [5 rows x 35 columns]

# %% [markdown]
# ___
# ### president_approval_polls_historical()

# %%
paph = fivethirtyeight.president_approval_polls_historical()
paph.head()
# Out:
#    poll_id  pollster_id    pollster  ...   yes    no alternate_answers
# 0    74225          568      YouGov  ...  42.0  53.0               4.0
# 1    74225          568      YouGov  ...  44.0  55.0               1.0
# 2    74226           23         ARG  ...  30.0  66.0               0.0
# 3    74226           23         ARG  ...  29.0  67.0               0.0
# 4    74224         1528  AtlasIntel  ...  44.6  53.9               1.5
#
# [5 rows x 35 columns]

# %% [markdown]
# ___
# ### vp_approval_polls()

# %%
vapp = fivethirtyeight.vp_approval_polls()
vapp.head()
# Out:
#    poll_id  pollster_id  ...    no alternate_answers
# 0    86959         1562  ...  41.0              21.0
# 1    86836         1562  ...  44.0              20.0
# 2    86726          320  ...  55.0               5.0
# 3    86726          320  ...  57.0               4.0
# 4    86651         1562  ...  44.0              21.0
#
# [5 rows x 35 columns]

# %% [markdown]
# ___
# ### congress_approval()

# %%
ca = fivethirtyeight.congress_approval()
ca.head()
# Out:
#    poll_id  pollster_id  pollster  ...   yes    no alternate_answers
# 0    87150          568    YouGov  ...  13.0  58.0              29.0
# 1    87150          568    YouGov  ...  13.0  65.0              21.0
# 2    87154          320  Monmouth  ...  14.0  82.0               4.0
# 3    87154          320  Monmouth  ...  14.0  82.0               4.0
# 4    87102          568    YouGov  ...  12.0  59.0              29.0
#
# [5 rows x 33 columns]

# %% [markdown]
# ___
# ### approval_averages()

# %%
aa = fivethirtyeight.approval_averages()
aa.head()
# Out:
#   politician/institution       date  ...         lo         hi
# 0               Congress 2024-06-12  ...  11.210452  24.690400
# 1               Congress 2024-06-12  ...  59.137450  74.210440
# 2               Congress 2024-06-11  ...  11.710428  25.281531
# 3               Congress 2024-06-11  ...  59.268416  74.440954
# 4               Congress 2024-06-10  ...  11.708023  25.279127
#
# [5 rows x 6 columns]

# %% [markdown]
# ___
# ### president_polls()

# %%
pp = fivethirtyeight.president_polls()
pp.head()
# Out:
#    poll_id  pollster_id  ...     candidate_name   pct
# 0    87162         1302  ...          Joe Biden  48.0
# 1    87162         1302  ...       Donald Trump  47.0
# 2    87162         1302  ...          Joe Biden  42.0
# 3    87162         1302  ...       Donald Trump  43.0
# 4    87162         1302  ...  Robert F. Kennedy   7.0
#
# [5 rows x 48 columns]

# %% [markdown]
# ___
# ### president_polls_historical()

# %%
pph = fivethirtyeight.president_polls_historical()
pph.head()
# Out:
# /home/ubuntu/env/lib/python3.10/site-packages/ots_backend/fivethirtyeight/datasets.py:110: DtypeWarning: Columns (16,17,26,28,31) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = read_csv(BASE_URL + 'president_polls_historical' + '.csv')
#    poll_id  pollster_id  ... candidate_name   pct
# 0    73830          940  ...      Joe Biden  51.0
# 1    73830          940  ...   Donald Trump  48.0
# 2    74946         1677  ...      Joe Biden  44.2
# 3    74946         1677  ...   Donald Trump  48.0
# 4    72621          383  ...      Joe Biden  49.0
#
# [5 rows x 48 columns]

# %% [markdown]
# ___
# ### presidential_general_averages()

# %%
pga = fivethirtyeight.presidential_general_averages()
pga.head()
# Out:
#              candidate       date  pct_trend_adjusted  ... pct_estimate  hi  lo
# 0  Joseph R. Biden Jr. 2020-11-03            37.82732  ...          NaN NaN NaN
# 1         Donald Trump 2020-11-03            57.36126  ...          NaN NaN NaN
# 2  Joseph R. Biden Jr. 2020-11-02            37.82732  ...          NaN NaN NaN
# 3         Donald Trump 2020-11-02            57.36126  ...          NaN NaN NaN
# 4  Joseph R. Biden Jr. 2020-11-01            38.07011  ...          NaN NaN NaN
#
# [5 rows x 9 columns]

# %% [markdown]
# ___
# ### president_primary_polls_historical()

# %%
ppph = fivethirtyeight.president_primary_polls_historical()
ppph.head()

# %% [markdown]
# ___
# ### presidential_primary_averages()

# %%
ppa = fivethirtyeight.presidential_primary_averages()
ppa.head()
# Out:
#              candidate       date  pct_estimate    state  ...  cycle  party  hi  lo
# 0        Tulsi Gabbard 2020-03-03      0.418470  Alabama  ...   2020    DEM NaN NaN
# 1    Michael Bloomberg 2020-03-03     15.571660  Alabama  ...   2020    DEM NaN NaN
# 2     Elizabeth Warren 2020-03-03      9.747683  Alabama  ...   2020    DEM NaN NaN
# 3      Bernard Sanders 2020-03-03     15.794730  Alabama  ...   2020    DEM NaN NaN
# 4  Joseph R. Biden Jr. 2020-03-03     43.368710  Alabama  ...   2020    DEM NaN NaN
#
# [5 rows x 9 columns]

# %% [markdown]
# ___
# ### house_polls()

# %%
hp = fivethirtyeight.house_polls()
hp.head()

# %% [markdown]
# ___
# ### house_polls_historical()

# %%
hph = fivethirtyeight.house_polls_historical()
hph.head()
# Out:
#    poll_id  pollster_id  ...      candidate_name   pct
# 0    81569          525  ...        Chris Pappas  50.0
# 1    81569          525  ...    Karoline Leavitt  49.0
# 2    81569          525  ...   Ann McLane Kuster  53.0
# 3    81569          525  ...        Robert Burns  45.0
# 4    81570          525  ...  Chellie M. Pingree  58.0
#
# [5 rows x 48 columns]

# %% [markdown]
# ___
# ### senate_polls()

# %%
sp = fivethirtyeight.senate_polls()
sp.head()

# %% [markdown]
# ___
# ### senate_polls_historical()

# %%
sph = fivethirtyeight.senate_polls_historical()
sph.head()
