# %%
from requests import get
from json import loads
from pandas import DataFrame

# %%
res = get('https://www.predictit.org/api/Market/7456/Contracts')
res = loads(res.content.decode('utf-8'))
res = DataFrame.from_dict(res)
res
# Out:
#    contractId        contractName  ...  displayOrder minimumClipSize
# 0       27485        Donald Trump  ...             0             100
# 1       27486           Joe Biden  ...             1             100
# 2       31066        Gavin Newsom  ...             2               1
# 3       31296  Robert Kennedy Jr.  ...             3               1
# 4       27487       Kamala Harris  ...             4               1
# 5       27484        Ron DeSantis  ...             5               1
# 6       31389         Nikki Haley  ...             6               1
# 7       28624      Pete Buttigieg  ...             7               1
# 8       31294     Vivek Ramaswamy  ...             8               1
# 9       31295           Tim Scott  ...             9               1
#
# [10 rows x 24 columns]
